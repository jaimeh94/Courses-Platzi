# %%
from google.colab import  drive #importamos google drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
! ls '/gdrive/My Drive/Investigación/Platzi/Inteligencia Artificial/Deep Learning - Pytorch' #descargamos a la carpeta
# Out:
# SetupColab.ipynb

# %%
#entramos a las carpatas descargadas 
# %cd '/gdrive/My Drive/Investigación/Platzi/Inteligencia Artificial/Deep Learning - Pytorch'
# Out:
# /gdrive/My Drive/Investigación/Platzi/Inteligencia Artificial/Deep Learning - Pytorch

# %%
# !git clone https://github.com/JuanPabloMF/dl-pytorch #clonamos un depoositorio de github
# Out:
# Cloning into 'dl-pytorch'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 36 (delta 18), reused 27 (delta 9), pack-reused 0
# Unpacking objects: 100% (36/36), done.

# %%
# %cd  'dl-pytorch'
 #entramos en el mismo
# Out:
# /gdrive/My Drive/Investigación/Platzi/Inteligencia Artificial/Deep Learning - Pytorch/dl-pytorch

# %%
# %ls #vemos lo que hay
# Out:
# datasets/  optimizers_viz.py  plot_helpers.py  utils.py

# %%
#entramos en una carpeta 
# %cd 'datasets'
# Out:
# /gdrive/MyDrive/Investigación/Platzi/Inteligencia Artificial/Deep Learning - Pytorch/dl-pytorch/datasets

# %%
# !unzip 64x64_SIGNS.zip #discomprimimos
# Out:
# Archive:  64x64_SIGNS.zip
#    creating: 64x64_SIGNS/
#   inflating: 64x64_SIGNS/.DS_Store
#    creating: 64x64_SIGNS/train_signs/
#   inflating: 64x64_SIGNS/train_signs/5_IMG_5556.jpg
#   inflating: 64x64_SIGNS/train_signs/3_IMG_6138.jpg
#   inflating: 64x64_SIGNS/train_signs/3_IMG_6104.jpg
#   inflating: 64x64_SIGNS/train_signs/5_IMG_5595.jpg
#   inflating: 64x64_SIGNS/train_signs/5_IMG_5581.jpg
#   inflating: 64x64_SIGNS/train_signs/1_IMG_4495.jpg
#   inflating: 64x64_SIGNS/train_signs/4_IMG_5357.jpg
#   inflating: 64x64_SIGNS/train_signs/2_IMG_4648.jpg
#   inflating: 64x64_SIGNS/train_signs/4_IMG_5343.jpg
#   inflating: 64x64_SIGNS/train_signs/2_IMG_4660.jpg
#   inflating: 64x64_SIGNS/train_signs/4_IMG_5419.jpg
#   inflating: 64x64_SIGNS/train_signs/1_IMG_4456.jpg
#   inflating: 64x64_SIGNS/train_signs/4_IMG_5394.jpg
#   inflating: 64x64_SIGNS/train_signs/1_IMG_4442.jpg
#   inflating: 64x64_SIGNS/train_signs/5_IMG_5620.jpg
#   inflating: 64x64_SIGNS/train_signs/2_IMG_4728.jpg
# ...

# %%
#le decimos donde hay una nueva libreria 
import sys   #importamos el modelos 
#le damos una ruta
course_path = '/gdrive/My Drive/Investigación/Platzi/Inteligencia Artificial/Deep Learning - Pytorch/dl-pytorch' 

#que la recuerde siempre 
sys.path.append(course_path)

# %%
# %cd ..
# Out:
# /gdrive/My Drive/Investigación/Platzi/Inteligencia Artificial/Deep Learning - Pytorch/dl-pytorch

# %%
import plot_helpers #vemos que podemos importat la librerioa 
#todo resulto bien

# %%
dir(plot_helpers) #vemos las cosas que tienen adentro
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'french',
#  'imshow',
#  'io',
#  'np',
#  'plot_cube',
#  'plot_rgb_image',
#  'plt',
#  'torch',
#  'visualize_model']
